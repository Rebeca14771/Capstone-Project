# %% [markdown]
# This Notebook will be mainly used for the capstone project of Coursera Course

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!"
# Out:
#   File "<ipython-input-3-5f80010f654f>", line 1
#     print "Hello Capstone Project Course!"
#                                          ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Hello Capstone Project Course!")?
